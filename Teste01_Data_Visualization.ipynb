# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasvx273/Data_Visualization/blob/main/Teste01_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Caderno voltado para treinos na visualização de dados** / *Escola: Sigmoidal*
#
# ---------------------------------------------------
#
# **Autor:** Lucas Pequeno Sterzeck / **Linkedin:** https://www.linkedin.com/in/lucas-p-a87365108/ / **E-mail:** lpsterzeck@outlook.com
#
# Feel  free to contact me.
#
# ----------------------------------------------------
#
# #Data Science
# #Python
# #Data Visualization

# %%
#Importação das bibliotecas utilizadas (Pandas e Matplotlib)
import pandas as pd
import matplotlib.pyplot as plt

#Biblioteca utilizada obtida através do curso de Python da Sigmoidal
df = pd.read_csv("https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/ocorrencias_aviacao.csv")

#Mudando ultima coluna para formato data
ocorrencia_dia = pd.to_datetime(df["ocorrencia_dia"])
#Mudando variavel acima para extrair somente o ano:::
ocorrencia_ano = ocorrencia_dia.dt.year

#Listar primeiras entradas extraídas da nova variavel.
ocorrencia_ano.head()
# Out:
# 0    2013
# 1    2016
# 2    2018
# 3    2013
# 4    2011
# Name: ocorrencia_dia, dtype: int64

# %%
#Tipos de variáveis
df.dtypes
# Out:
# codigo_ocorrencia                   int64
# ocorrencia_classificacao           object
# ocorrencia_tipo                    object
# ocorrencia_tipo_categoria          object
# ocorrencia_tipo_icao               object
# ocorrencia_latitude               float64
# ocorrencia_longitude              float64
# ocorrencia_cidade                  object
# ocorrencia_uf                      object
# ocorrencia_pais                    object
# ocorrencia_aerodromo               object
# ocorrencia_dia                     object
# ocorrencia_horario                 object
# investigacao_aeronave_liberada     object
# investigacao_status                object
# divulgacao_relatorio_numero        object
# divulgacao_relatorio_publicado     object
# divulgacao_dia_publicacao          object
# total_recomendacoes                 int64
# total_aeronaves_envolvidas          int64
# ocorrencia_saida_pista             object
# ocorrencia_dia_extracao            object
# dtype: object

# %% [markdown]
# **Gráfico Histograma**
#
# O histograma também é conhecido como sendo um gráfico de distribuição de frequências.

# %%
x = ocorrencia_ano
y = df["ocorrencia_classificacao"]
z = df["ocorrencia_tipo"]

plt.hist(ocorrencia_ano, color="#983D3D", bins=11)
plt.title("Quantidade de ocorrências por ano")
plt.xlabel("Período em anos")
plt.ylabel("Ocorrências")
plt.show()

plt.hist(ocorrencia_ano, color="#293D3D", bins=21, density=True)
plt.title("Quantidade de ocorrências por ano")
plt.xlabel("Período em anos")
plt.ylabel("Ocorrências")
plt.show()

# %% [markdown]
# **Gráfico Linhas**
#
# O gráfico de linha é um tipo de gráfico que mostra a informação em forma de um conjunto de pontos (markers) conectados por segmentos de linha reta.

# %%
#base de dados da Sigmoidal, que contempla casos de dengue no brasil.
base = pd.read_csv("https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/dengue-dataset.csv") 
x = pd.to_datetime(base["data"])
#Acima convertendo a base coluna: DATA para dia, pois está como String. (Ordem correta do "pd" ano-dia-mes)
y = base["casos-confirmados"]
scale_factor = y.mean()
tempmedia = base["temperatura-media"]
tempminima = base["temperatura-mininima"]
tempmaxima = base["temperatura-maxima"]

# Teste com sobreposição em grafico de linha
plt.plot(x, y, label="C. Confirmados")
plt.plot(x, tempmedia * scale_factor, label="T. Média")
plt.plot(x, tempminima * scale_factor, label="T. Mínima")
plt.plot(x, tempmaxima * scale_factor, label="T. Máxima")
plt.title("Casos confirmados x Temperaturas")
plt.xlabel("Exemplo eixo X")
plt.ylabel("Exemplo eixo Y")
plt.legend()
plt.show()

# Gráfico de casos confirmados
plt.plot(x, y, label="Casos Confirmados")
plt.title("Casos confirmados por período")
plt.xlabel("Exemplo eixo X")
plt.ylabel("Exemplo eixo Y")
plt.legend()
plt.show()

# Gráfico com temperaturas / Será utilizado novamente em outra visualização a seguir!!!
plt.plot(x, tempmedia * scale_factor, label="T. Média")
plt.plot(x, tempminima * scale_factor, label="T. Mínima")
plt.plot(x, tempmaxima * scale_factor, label="T. Máxima")
plt.title("Variação de temperaturas")
plt.xlabel("Exemplo eixo X")
plt.ylabel("Exemplo eixo Y")
plt.legend()
plt.show()

# %% [markdown]
# **Gráfico Boxplot**
#
# *Boxplot*, ou diagrama de caixa em português, é uma ferramenta estatística que consegue representar a variação de uma variável utilizando quartis.
#
# <center><img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c9/Elements_of_a_boxplot_pt.svg/2560px-Elements_of_a_boxplot_pt.svg.png"width="450px"></center>

# %%
# Re-importando as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/dengue-dataset.csv")

print("Estrutura HEAD: \n", df.head())
# Gráfico boxplot de temperaturas
df.boxplot(["temperatura-media", 'temperatura-mininima', 'temperatura-maxima'])
plt.title("Média de temperaturas")
plt.xlabel("Variações de Temperaturas")
plt.ylabel("Médias em Cº")
plt.show()

df.boxplot(["temperatura-media"])
plt.title("Boxplot temperatura média")
plt.xlabel("Variações de Temperaturas")
plt.ylabel("Médias em Cº")
plt.show()

df.boxplot(["temperatura-mininima"])
plt.title("Boxplot temperatura mínima")
plt.xlabel("Variações de Temperaturas")
plt.ylabel("Médias em Cº")
plt.show()

df.boxplot(["temperatura-maxima"])
plt.title("Boxplot temperatura máxima")
plt.xlabel("Variações de Temperaturas")
plt.ylabel("Médias em Cº")
plt.show()
# Out:
# Estrutura HEAD:
#           data  casos-confirmados  ...  temperatura-mininima  temperatura-maxima
# 0  1998-01-01                237  ...                  20.2                28.1
# 1  1998-02-01                331  ...                  20.0                28.0
# 2  1998-03-01                562  ...                  22.4                27.2
# 3  1998-04-01                187  ...                  18.1                26.0
# 4  1998-05-01                 32  ...                  15.7                22.9
#
# [5 rows x 6 columns]

# %% [markdown]
# **Gráfico Barras**
#
# O gráfico de barras é um gráfico composto por barras de formato retangular.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/entrada_passageiro_linha1.csv")
print(df.head(),"\n","----"*10)
print(df.tail(),"\n","----"*10)
print("Tipos de dados trabalhados:\n",df.dtypes,"\n","----"*10)
# Out:
#            Estação  Entradas
# 0        Jabaquara      90.0
# 1        Conceição      40.0
# 2        São Judas      20.0
# 3            Saúde      36.0
# 4  Praça da Árvore      22.0
#  ----------------------------------------
#                           Estação  Entradas
# 19                        Santana    64.000
# 20  Jardim São Paulo-Ayrton Senna    14.000
# 21                 Parada Inglesa    16.000
# 22                       Tucuruvi    70.000
# 23                          TOTAL     1.425
#  ----------------------------------------
# Tipos de dados trabalhados:
#  Estação      object
# Entradas    float64
# dtype: object
#  ----------------------------------------

# %%
#Retirar da TAIL essa linha de "TOTAL":
df.drop(index=23, axis=0, inplace=True)
print(df.tail(),"\n","----"*10)
# Out:
#                           Estação  Entradas
# 18                      Carandiru      15.0
# 19                        Santana      64.0
# 20  Jardim São Paulo-Ayrton Senna      14.0
# 21                 Parada Inglesa      16.0
# 22                       Tucuruvi      70.0
#  ----------------------------------------

# %%
# Gráfico de barras
df.plot(x="Estação", y="Entradas", kind="bar", color="#FFC733")
plt.title("Número de entradas por estação")
plt.xlabel("Estações")
plt.ylabel("Entradas")
plt.show()

# %% [markdown]
# **Gráfico Scatter**
#
# O gráfico de dispersão (*scatter plot*) é um gráfico bi-dimensional para visualização de dados que usa pontos para representar o valor entre duas variáveis diferentes.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/housing.csv")
df.plot.scatter(x='median_income', y='median_house_value', s=0.5)
df.plot.scatter(x='latitude', y='median_house_value', s=0.5)
df.plot.scatter(x='latitude', y='median_income', s=0.5)
plt.show()

# %% [markdown]
# **Gráfico Waffle**
#
# <img src="http://sigmoidal.ai/wp-content/uploads/2019/10/grafico_de_waffle.png" height="250px">

# %%
#Exemplo adaptado fornecido no curso de python sobre Gráfico waffle
# Only on fist time do: !pip install pywaffle -q
import matplotlib.pyplot as plt
from pywaffle import Waffle

# exemplo de Waffle
fig = plt.figure(
                FigureClass=Waffle,
                rows=4,
                columns=10,
                values={'Bolacha': 66,
                        'Biscoito': 160,
                        'Salgadinho': 180},
                icons='star',
                legend={'loc': 'upper left',
                        'bbox_to_anchor': (1, 1)}
                )

fig.set_tight_layout(False)
plt.show()
# Out:
# <Waffle size 432x288 with 1 Axes>

# %% [markdown]
# **Gráficos do Pandas Profiling**
#
# Quando estamos tendo contato com um dataset pela primeira vez, buscamos ganhar a maior consciência situacional possível. Esse é o motivo de olharmos tanta coisa, pois conseguimos gerar insights preciosos.

# %%
# !pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip -q
import pandas as pd
from pandas_profiling import ProfileReport
df = pd.read_csv("https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/ocorrencias_aviacao.csv")
# Out:
#      | 25.9 MB 155 kB/s
#      |████████████████████████████████| 10.9 MB 14.1 MB/s
#      |████████████████████████████████| 596 kB 50.4 MB/s
#      |████████████████████████████████| 102 kB 11.7 MB/s
#      |████████████████████████████████| 675 kB 55.0 MB/s
#      |████████████████████████████████| 4.7 MB 44.0 MB/s
#      |████████████████████████████████| 63 kB 1.7 MB/s
#      |████████████████████████████████| 812 kB 53.3 MB/s
#      |████████████████████████████████| 38.1 MB 1.4 MB/s
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.

# %%
# criar ProfileReport
report = ProfileReport(df)

# %%
# criar visualização iframe
report.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.1&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-02-09 20:51:24.021838&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
